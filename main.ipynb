# %%
# !git clone https://github.com/coqui-ai/TTS
# Out:
# Cloning into 'TTS'...
# remote: Enumerating objects: 29880, done.
# remote: Counting objects: 100% (283/283), done.
# remote: Compressing objects: 100% (152/152), done.
# remote: Total 29880 (delta 171), reused 210 (delta 127), pack-reused 29597
# Receiving objects: 100% (29880/29880), 159.26 MiB | 27.46 MiB/s, done.
# Resolving deltas: 100% (21650/21650), done.

# %%
# !cd TTS

# %%
# !pip install .
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Processing /content/TTS
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Using cached Cython-0.29.28-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (1.9 MB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 289.9/289.9 kB 7.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 35.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.1/71.1 kB 7.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.9/80.9 kB 7.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.2/45.2 kB 4.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 65.8 MB/s eta 0:00:00
# ...

# %%
# !apt-get install -y espeak
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   espeak-data libespeak1 libportaudio2 libsonic0
# The following NEW packages will be installed:
#   espeak espeak-data libespeak1 libportaudio2 libsonic0
# 0 upgraded, 5 newly installed, 0 to remove and 24 not upgraded.
# Need to get 1,220 kB of archives.
# After this operation, 3,060 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal/universe amd64 libportaudio2 amd64 19.6.0-1build1 [65.4 kB]
# Get:2 http://archive.ubuntu.com/ubuntu focal/main amd64 libsonic0 amd64 0.2.0-8 [13.1 kB]
# Get:3 http://archive.ubuntu.com/ubuntu focal/universe amd64 espeak-data amd64 1.48.04+dfsg-8build1 [932 kB]
# Get:4 http://archive.ubuntu.com/ubuntu focal/universe amd64 libespeak1 amd64 1.48.04+dfsg-8build1 [147 kB]
# ...

# %% [markdown]
# restart the runtime

# %%
from TTS.utils.synthesizer import Synthesizer
from TTS.config import load_config

# Paths to the model and config files
model_path = "checkpoint_1010000.pth"
config_path = "config.json"

# Load the configuration
config = load_config(config_path)

# Initialize the synthesizer
synthesizer = Synthesizer(model_path, config_path)

def generate_spongebob_sound(text):
    speaker_id = "VCTK_spongebob"
    wav = synthesizer.tts(text, speaker_id)
    return wav

# Example usage:
text = "Ted rode a bike for 7 miles"
wav = generate_spongebob_sound(text)


out_path = "test2.wav"
synthesizer.save_wav(wav, out_path)
# Out:
#  > Using model: vits
#  > Setting up Audio Processor...
#  | > sample_rate:22050
#  | > resample:False
#  | > num_mels:80
#  | > log_func:np.log10
#  | > min_level_db:0
#  | > frame_shift_ms:None
#  | > frame_length_ms:None
#  | > ref_level_db:None
#  | > fft_size:1024
#  | > power:None
#  | > preemphasis:0.0
#  | > griffin_lim_iters:None
#  | > signal_norm:None
#  | > symmetric_norm:None
#  | > mel_fmin:0
#  | > mel_fmax:None
#  | > pitch_fmin:None
#  | > pitch_fmax:None
#  | > spec_gain:20.0
#  | > stft_pad_mode:reflect
#  | > max_norm:1.0
#  | > clip_norm:True
#  | > do_trim_silence:False
#  | > trim_db:60
#  | > do_sound_norm:False
#  | > do_amp_to_db_linear:True
#  | > do_amp_to_db_mel:True
#  | > do_rms_norm:False
#  | > db_level:None
#  | > stats_path:None
#  | > base:10
#  | > hop_length:256
#  | > win_length:1024
#  > initialization of speaker-embedding layers.
#  > Text splitted to sentences.
# ['Ted rode a bike for 7 miles']
#  > Processing time: 4.311088562011719
# ...

# %%
import os

def find_file(root_directory, target_file):
    for root, dirs, files in os.walk(root_directory):
        if target_file in files:
            return os.path.join(root, target_file)
    return None

# Usage:
root_directory = "/"  # start from root directory
target_file = "speakers.pth"  # the file to search for

file_path = find_file(root_directory, target_file)

if file_path is None:
    print(f"{target_file} not found.")
else:
    print(f"Found {target_file} at {file_path}")
# Out:
# Found speakers.pth at /content/drive/MyDrive/speakers.pth
